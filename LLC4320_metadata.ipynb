# %% [markdown]
# ### Import Libraries

# %%
import xarray as xr
import OpenVisus as ov
import openvisuspy as ovp
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Extract Latitude and Longitude from the netcdf file

# %% [markdown]
# Please download it from here: https://mega.nz/file/SB1UFbRA#h2FH1vmbHi8mvuYa9NQrd_MLaruoIaxP_M8yD-EEAeM
#
# Please send an email to aashishpanta0@gmail.com if you have trouble accessing it.

# %%
ds=xr.open_dataset('./llc4320_latlon.nc')
lat_center = ds["latitude"].values
lon_center = ds["longitude"].values
ds
# Out:
# <xarray.Dataset> Size: 2GB
# Dimensions:    (y: 12960, x: 17280)
# Coordinates:
#   * y          (y) int64 104kB 0 1 2 3 4 5 ... 12955 12956 12957 12958 12959
#   * x          (x) int64 138kB 0 1 2 3 4 5 ... 17275 17276 17277 17278 17279
# Data variables:
#     latitude   (y, x) float32 896MB -88.18 -88.18 -88.18 ... 67.5 67.5 67.5
#     longitude  (y, x) float32 896MB -114.9 -114.9 -114.9 ... -38.01 -38.0 -38.0
# Attributes:
#     title:        LLC4320 Mosaic Grid
#     description:  Latitude and Longitude mosaic from LLC4320 faces 0, 1, 3, 4
#     source:       Generated from MITgcm LLC4320 binary grid data

# %% [markdown]
# ### Set Variables

# %%
temperature="pelican://osg-htc.org/nasa/nsdf/climate1/llc4320/idx/theta/theta_llc4320_x_y_depth.idx" #aka theta
salinity="pelican://osg-htc.org/nasa/nsdf/climate1/llc4320/idx/salt/salt_llc4320_x_y_depth.idx"
w="pelican://osg-htc.org/nasa/nsdf/climate2/llc4320/idx/w/w_llc4320_x_y_depth.idx"

# %% [markdown]
# ### Use Array Index to extract Data and Lat/Lon

# %%
def extract_data_latlon(
  field, lat_center, lon_center, x_range, y_range, z=[0, 1], quality=0
):
  db = ovp.LoadDataset(field)
  data = db.db.read(x=x_range, y=y_range, z=z, quality=quality)[0, :, :]
  lat = lat_center[y_range[0] : y_range[1], x_range[0] : x_range[1]]
  lon = lon_center[y_range[0] : y_range[1], x_range[0] : x_range[1]]
  return data, lat, lon

# %%
x_range = [6800, 9600]
y_range = [5200, 7600]
data_sub, lat_sub, lon_sub = extract_data_latlon(temperature, lat_center, lon_center, x_range, y_range)
# Out:
# ---------------------------------------------------------------------------
# SystemError                               Traceback (most recent call last)
# Cell In[7], line 3
#       1 x_range = [6800, 9600]
#       2 y_range = [5200, 7600]
# ----> 3 data_sub, lat_sub, lon_sub = extract_data_latlon(temperature, lat_center, lon_center, x_range, y_range)
#
# Cell In[6], line 4, in extract_data_latlon(field, lat_center, lon_center, x_range, y_range, z, quality)
#       1 def extract_data_latlon(
#       2   field, lat_center, lon_center, x_range, y_range, z=[0, 1], quality=0
#       3 ):
# ----> 4   db = ovp.LoadDataset(field)
#       5   data = db.db.read(x=x_range, y=y_range, z=z, quality=quality)[0, :, :]
#       6   lat = lat_center[y_range[0] : y_range[1], x_range[0] : x_range[1]]
#
# File ~/Documents/Faks/MAGISTERIJ/1_LETNIK/ZIMSKI/IOI/PROJEKTNA/.venv/lib/python3.10/site-packages/openvisuspy/backend.py:710, in LoadDataset(url)
#     708 	return Signal1DDataset(url)
#     709 else:
# --> 710 	return OpenVisusDataset(url)
#
# File ~/Documents/Faks/MAGISTERIJ/1_LETNIK/ZIMSKI/IOI/PROJEKTNA/.venv/lib/python3.10/site-packages/openvisuspy/backend.py:250, in OpenVisusDataset.__init__(self, url)
#     239 if all([
#     240 		url.startswith("http"),
#     241 		"mod_visus" in url,
#    (...)
#     245 		"~auth_password" not in url,
#     246  	]) :
#     248 	url=url + f"&~auth_username={os.environ['MODVISUS_USERNAME']}&~auth_password={os.environ['MODVISUS_PASSWORD']}"
# --> 250 self.db=ov.LoadDataset(url)
#
# File ~/Documents/Faks/MAGISTERIJ/1_LETNIK/ZIMSKI/IOI/PROJEKTNA/.venv/lib/python3.10/site-packages/OpenVisus/VisusDbPy.py:155, in LoadDataset(url, cache_dir)
#     153 def LoadDataset(url, cache_dir=""):
#     154 	from OpenVisus.dataset import PyDataset
# --> 155 	return PyDataset(LoadDatasetCpp(url, cache_dir))
#
# File ~/Documents/Faks/MAGISTERIJ/1_LETNIK/ZIMSKI/IOI/PROJEKTNA/.venv/lib/python3.10/site-packages/OpenVisus/VisusDbPy.py:1092, in LoadDatasetCpp(*args)
#    1091 def LoadDatasetCpp(*args):
# -> 1092     return _VisusDbPy.LoadDatasetCpp(*args)
#
# SystemError: Error in swig director code what Visus throwing exception where(/Users/m1/github.com/OpenVisus/Libs/Db/src/Dataset.cpp:313) what(empty content) where /Users/m1/github.com/OpenVisus/build-cpython-3.10/Release/VisusDbPyPYTHON_wrap.cxx : 30433
#  <no error?>

# %%
plt.figure(figsize=(8, 5))
plt.imshow(
  data_sub,
  cmap="turbo",
  origin="lower",
  extent=[lon_sub.min(), lon_sub.max(), lat_sub.min(), lat_sub.max()],
)
plt.colorbar(label="Theta")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.title("Extracted Subregion")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Use Lat/Lon to extract corresponding data

# %%
def extract_data_by_latlon_range(field, lat_center, lon_center, 
                                  lat_range, lon_range, z=[0,1], quality=0):
    db = ovp.LoadDataset(field)
    
    mask = (
        (lat_center >= lat_range[0]) & (lat_center <= lat_range[1]) &
        (lon_center >= lon_range[0]) & (lon_center <= lon_range[1])
    )

    y_indices, x_indices = np.where(mask)

    if len(x_indices) == 0 or len(y_indices) == 0:
        raise ValueError("No data found in the given lat/lon range.")

    x_min = int(x_indices.min())
    x_max = int(x_indices.max()) + 1
    y_min = int(y_indices.min())
    y_max = int(y_indices.max()) + 1

    data = db.db.read(x=[x_min, x_max], y=[y_min, y_max], z=z, quality=quality)[0, :, :]
    lat = lat_center[y_min:y_max, x_min:x_max]
    lon = lon_center[y_min:y_max, x_min:x_max]

    return data, lat, lon

# %%
lat_range = [-40, -10]
lon_range = [105, 160]

data, lat, lon = extract_data_by_latlon_range(temperature, lat_center, lon_center, lat_range, lon_range)

# %%
plt.figure(figsize=(8, 5))
plt.imshow(data, cmap="turbo", origin="lower", extent=[
    lon.min(), lon.max(), lat.min(), lat.max()])
plt.colorbar(label="Theta")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.title("Extracted Subregion")
plt.tight_layout()
plt.show()
